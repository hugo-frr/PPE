# %% [markdown]
# # 04 - Enriched LSTM

# %%
import sys
from pathlib import Path

base_dir = Path.cwd().resolve().parent if Path.cwd().name=='notebooks' else Path.cwd()
sys.path.append(str(base_dir / "src"))

from models.lstm_enriched import train_enriched
model = train_enriched()
