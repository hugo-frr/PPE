# %% [markdown]
# # 02 - Préprocessing via src

# %%
import sys
from pathlib import Path

base_dir = Path("/Users/hugoferre/Documents/PPE/ppe")
sys.path.append(str(base_dir / "src"))

from data_utils import preprocess_and_save

preprocess_and_save()
# Out:
# /Users/hugoferre/Documents/PPE/ppe/src/data_utils.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#
# [*********************100%***********************]  3 of 3 completed
# ✅ Données téléchargées et sauvegardées dans /Users/hugoferre/Documents/PPE/ppe/data/raw/prices.csv
# ✅ Préprocessing terminé et sauvegardé dans data/processed
