# %% [markdown]
# # 02 - Préprocessing via src

# %%
import sys
from pathlib import Path

base_dir = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(base_dir / "src"))

from data_utils import preprocess_and_save

preprocess_and_save()
# Out:
#             Airbus_price  Airbus_ret  LVMH_price  LVMH_ret  Stellantis_price  \
# Date
# 2018-01-03     76.716863    0.013918  214.351278 -0.011859           3.30672
# 2018-01-04     78.021907    0.016868  217.790050  0.015915           3.30672
# 2018-01-05     78.148798    0.001625  220.082564  0.010471           3.30672
# 2018-01-08     78.502251    0.004513  218.671760 -0.006431           3.30672
# 2018-01-09     79.073212    0.007247  218.715868  0.000202           3.30672
# ...                  ...         ...         ...       ...               ...
# 2025-11-12    213.399994    0.004462  650.400024  0.017527           9.49300
# 2025-11-13    213.350006   -0.000234  654.700012  0.006590           9.37700
# 2025-11-14    207.850006   -0.026117  643.900024 -0.016634           9.13600
# 2025-11-17    210.350006    0.011956  634.500000 -0.014706           9.04500
# 2025-11-18    206.649994   -0.017746  616.500000 -0.028779           8.62500
#
#             Stellantis_ret  CAC40_price  CAC40_ret  TariffEvent
# Date
# 2018-01-03        0.000000  5347.629883   0.005417            0
# 2018-01-04        0.000000  5430.720215   0.015418            0
# 2018-01-05        0.000000  5470.750000   0.007344            0
# 2018-01-08        0.000000  5499.149902   0.005178            0
# 2018-01-09        0.000000  5525.669922   0.004811            0
# ...                    ...          ...        ...          ...
# 2025-11-12        0.010909  8280.969727   0.013516            0
# 2025-11-13       -0.012295  8314.230469   0.004008            0
# 2025-11-14       -0.026037  8202.480469  -0.013532            0
# 2025-11-17       -0.010010  8176.100098  -0.003221            0
# 2025-11-18       -0.047547  8022.209961  -0.019001            0
#
# [2018 rows x 9 columns]
