# %% [markdown]
# # 03 - Baseline LSTM

# %%
import sys
from pathlib import Path

# Chemin vers la racine de ton projet
base_dir = Path("/Users/hugoferre/Documents/ppe_trump_project")
sys.path.append(str(base_dir / "src"))

from models.lstm_baseline import train_baseline

model = train_baseline()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 8
#       5 base_dir = Path("/Users/hugoferre/Documents/ppe_trump_project")
#       6 sys.path.append(str(base_dir / "src"))
# ----> 8 from models.lstm_baseline import train_baseline
#      10 model = train_baseline()
#
# ModuleNotFoundError: No module named 'models'
