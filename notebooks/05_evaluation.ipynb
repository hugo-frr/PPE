# %% [markdown]
# # 05 - Évaluation

# %%
import sys
from pathlib import Path

base_dir = Path.cwd().resolve().parent if Path.cwd().name=='notebooks' else Path.cwd()
sys.path.append(str(base_dir / "src"))

from evaluation.metrics import evaluate_models
rmse_base,rmse_enriched,mae_base,mae_enriched = evaluate_models()
rmse_base,rmse_enriched,mae_base,mae_enriched
# Out:
# [Baseline] RMSE=4.7254 | MAE=3.6847 | MAPE=0.0231
# [Enriched] RMSE=4.8835 | MAE=3.7304 | MAPE=0.0226
# [OK] Comparaison sauvegardée: /Users/hugoferre/Documents/PPE/ppe/data/reports/model_comparison.csv
# (4.7254282197215955, 4.883520847057731, 3.684694290161133, 3.73038387298584)
